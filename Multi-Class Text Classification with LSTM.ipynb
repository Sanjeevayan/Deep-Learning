# %% [markdown]
# # https://towardsdatascience.com/multi-class-text-classification-with-lstm-1590bee1bd17

# %%
import pandas as pd
import os
import re
import spacy
from gensim.models.phrases import Phrases, Phraser
from time import time 
import multiprocessing
from gensim.models import Word2Vec
import bokeh.plotting as bp
from bokeh.models import HoverTool, BoxSelectTool
from bokeh.plotting import figure, show, output_notebook
from sklearn.manifold import TSNE
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.preprocessing import scale
import keras 
from keras.models import Sequential, Model 
from keras import layers
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Dropout, Input, Embedding
from keras.layers.merge import Concatenate
from sklearn.feature_extraction.text import TfidfVectorizer
#from wordcloud import WordCloud
from nltk.tokenize import RegexpTokenizer
from sklearn.metrics import confusion_matrix
# Out:
# /Users/kumarsanjeev/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
path = "/Users/KumarSanjeev/Downloads/us-consumer-finance-complaints/consumer_complaints.csv"

# %%
df = pd.read_csv(path)
df
# Out:
# /Users/kumarsanjeev/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (5,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        date_received                  product  \
# 0         08/30/2013                 Mortgage
# 1         08/30/2013                 Mortgage
# 2         08/30/2013         Credit reporting
# 3         08/30/2013             Student loan
# 4         08/30/2013          Debt collection
# 5         08/30/2013              Credit card
# 6         08/30/2013              Credit card
# 7         08/30/2013  Bank account or service
# 8         08/30/2013  Bank account or service
# 9         09/17/2013                 Mortgage
# 10        08/30/2013          Debt collection
# 11        08/30/2013                 Mortgage
# 12        08/30/2013                 Mortgage
# 13        08/30/2013                 Mortgage
# 14        09/10/2013          Debt collection
# 15        09/17/2013              Credit card
# 16        09/17/2013          Debt collection
# 17        09/24/2013         Credit reporting
# 18        09/24/2013          Debt collection
# 19        09/17/2013         Credit reporting
# 20        09/17/2013              Credit card
# 21        09/24/2013          Debt collection
# 22        09/24/2013                 Mortgage
# 23        09/10/2013          Debt collection
# 24        09/10/2013                 Mortgage
# 25        09/24/2013  Bank account or service
# 26        09/24/2013  Bank account or service
# 27        09/10/2013              Credit card
# 28        09/17/2013          Debt collection
# 29        08/30/2013                 Mortgage
# ...              ...                      ...
# 555927    12/07/2015         Credit reporting
# 555928    10/14/2015              Credit card
# 555929    08/05/2015  Bank account or service
# 555930    07/13/2013                 Mortgage
# 555931    12/05/2013                 Mortgage
# 555932    11/19/2015  Bank account or service
# 555933    09/10/2012  Bank account or service
# 555934    01/18/2016                 Mortgage
# 555935    03/20/2015            Consumer Loan
# 555936    09/14/2012                 Mortgage
# 555937    06/30/2014         Credit reporting
# 555938    09/10/2012              Credit card
# 555939    04/15/2013             Student loan
# 555940    11/05/2014                 Mortgage
# 555941    01/05/2016                 Mortgage
# 555942    08/28/2015                 Mortgage
# 555943    04/13/2015          Debt collection
# 555944    12/23/2015          Debt collection
# 555945    10/27/2015             Prepaid card
# 555946    05/30/2014                 Mortgage
# 555947    10/05/2012  Bank account or service
# 555948    05/09/2014  Bank account or service
# 555949    03/16/2016  Bank account or service
# 555950    01/21/2014          Debt collection
# 555951    05/17/2012              Credit card
# 555952    07/01/2014                 Mortgage
# 555953    07/01/2014                 Mortgage
# 555954    07/10/2012                 Mortgage
# 555955    04/14/2015          Debt collection
# 555956    08/14/2014          Debt collection
#
#                                    sub_product  \
# 0                               Other mortgage
# 1                               Other mortgage
# 2                                          NaN
# 3                     Non-federal student loan
# 4                                  Credit card
# 5                                          NaN
# 6                                          NaN
# 7                             Checking account
# 8                             Checking account
# 9       Conventional adjustable mortgage (ARM)
# 10       Other (i.e. phone, health club, etc.)
# 11                              Other mortgage
# 12      Conventional adjustable mortgage (ARM)
# 13                              Other mortgage
# 14                                 Credit card
# 15                                         NaN
# 16                                 Credit card
# 17                                         NaN
# 18                    Non-federal student loan
# 19                                         NaN
# 20                                         NaN
# 21                    Non-federal student loan
# 22                                FHA mortgage
# 23                                 Credit card
# 24                 Conventional fixed mortgage
# 25                  Other bank product/service
# 26                            Checking account
# 27                                         NaN
# 28                                    Mortgage
# 29                 Conventional fixed mortgage
# ...                                        ...
# 555927                                     NaN
# 555928                                     NaN
# 555929              Other bank product/service
# 555930                          Other mortgage
# 555931                          Other mortgage
# 555932             (CD) Certificate of deposit
# 555933                        Checking account
# 555934  Conventional adjustable mortgage (ARM)
# 555935                            Vehicle loan
# 555936                          Other mortgage
# 555937                                     NaN
# 555938                                     NaN
# 555939                Non-federal student loan
# 555940                          Other mortgage
# 555941                          Other mortgage
# 555942                          Other mortgage
# 555943                             Credit card
# 555944   Other (i.e. phone, health club, etc.)
# 555945                    General purpose card
# 555946                          Other mortgage
# 555947                        Checking account
# 555948             (CD) Certificate of deposit
# 555949                        Checking account
# 555950                             Credit card
# 555951                                     NaN
# 555952                          Other mortgage
# 555953                          Other mortgage
# 555954             Conventional fixed mortgage
# 555955                           I do not know
# 555956                           I do not know
#
#                                            issue  \
# 0       Loan modification,collection,foreclosure
# 1       Loan servicing, payments, escrow account
# 2         Incorrect information on credit report
# 3                             Repaying your loan
# 4             False statements or representation
# 5                   Application processing delay
# 6                  Credit line increase/decrease
# 7                       Deposits and withdrawals
# 8                       Deposits and withdrawals
# 9       Loan modification,collection,foreclosure
# 10         Cont'd attempts collect debt not owed
# 11      Loan servicing, payments, escrow account
# 12                Credit decision / Underwriting
# 13      Application, originator, mortgage broker
# 14                         Communication tactics
# 15                                      Late fee
# 16                         Communication tactics
# 17        Incorrect information on credit report
# 18           Improper contact or sharing of info
# 19        Incorrect information on credit report
# 20                              Billing disputes
# 21           Improper contact or sharing of info
# 22      Loan modification,collection,foreclosure
# 23                         Communication tactics
# 24      Loan modification,collection,foreclosure
# 25      Making/receiving payments, sending money
# 26                      Deposits and withdrawals
# 27                                       Rewards
# 28                         Communication tactics
# 29      Loan modification,collection,foreclosure
# ...                                          ...
# 555927    Incorrect information on credit report
# 555928     Identity theft / Fraud / Embezzlement
# 555929   Account opening, closing, or management
# 555930  Loan modification,collection,foreclosure
# 555931  Loan modification,collection,foreclosure
# 555932   Account opening, closing, or management
# 555933   Account opening, closing, or management
# 555934  Loan modification,collection,foreclosure
# 555935                Managing the loan or lease
# 555936  Loan modification,collection,foreclosure
# 555937    Incorrect information on credit report
# 555938                      APR or interest rate
# 555939                        Repaying your loan
# 555940  Loan modification,collection,foreclosure
# 555941  Loan modification,collection,foreclosure
# 555942  Loan modification,collection,foreclosure
# 555943     Cont'd attempts collect debt not owed
# 555944     Cont'd attempts collect debt not owed
# 555945     Managing, opening, or closing account
# 555946  Loan servicing, payments, escrow account
# 555947                  Deposits and withdrawals
# 555948     Problems caused by my funds being low
# 555949   Account opening, closing, or management
# 555950     Cont'd attempts collect debt not owed
# 555951                          Billing disputes
# 555952  Loan modification,collection,foreclosure
# 555953  Loan servicing, payments, escrow account
# 555954  Loan modification,collection,foreclosure
# 555955                     Communication tactics
# 555956     Cont'd attempts collect debt not owed
#
#                                     sub_issue consumer_complaint_narrative  \
# 0                                         NaN                          NaN
# 1                                         NaN                          NaN
# 2                              Account status                          NaN
# 3                          Repaying your loan                          NaN
# 4           Attempted to collect wrong amount                          NaN
# 5                                         NaN                          NaN
# 6                                         NaN                          NaN
# 7                                         NaN                          NaN
# 8                                         NaN                          NaN
# 9                                         NaN                          NaN
# 10                              Debt was paid                          NaN
# 11                                        NaN                          NaN
# 12                                        NaN                          NaN
# 13                                        NaN                          NaN
# 14                  Called outside of 8am-9pm                          NaN
# 15                                        NaN                          NaN
# 16      Used obscene/profane/abusive language                          NaN
# 17         Reinserted previously deleted info                          NaN
# 18      Talked to a third party about my debt                          NaN
# 19                    Information is not mine                          NaN
# 20                                        NaN                          NaN
# 21      Talked to a third party about my debt                          NaN
# 22                                        NaN                          NaN
# 23                  Called outside of 8am-9pm                          NaN
# 24                                        NaN                          NaN
# 25                                        NaN                          NaN
# 26                                        NaN                          NaN
# 27                                        NaN                          NaN
# 28                 Frequent or repeated calls                          NaN
# 29                                        NaN                          NaN
# ...                                       ...                          ...
# 555927                         Account status                          NaN
# 555928                                    NaN                          NaN
# 555929                                    NaN                          NaN
# 555930                                    NaN                          NaN
# 555931                                    NaN                          NaN
# 555932                                    NaN                          NaN
# 555933                                    NaN                          NaN
# 555934                                    NaN                          NaN
# 555935                                    NaN                          NaN
# 555936                                    NaN                          NaN
# 555937                Information is not mine                          NaN
# 555938                                    NaN                          NaN
# 555939                     Repaying your loan                          NaN
# 555940                                    NaN                          NaN
# 555941                                    NaN                          NaN
# 555942                                    NaN                          NaN
# 555943                       Debt is not mine                          NaN
# 555944                       Debt is not mine                          NaN
# 555945                                    NaN                          NaN
# 555946                                    NaN                          NaN
# 555947                                    NaN                          NaN
# 555948                                    NaN                          NaN
# 555949                                    NaN                          NaN
# 555950                       Debt is not mine                          NaN
# 555951                                    NaN                          NaN
# 555952                                    NaN                          NaN
# 555953                                    NaN                          NaN
# 555954                                    NaN                          NaN
# 555955             Frequent or repeated calls                          NaN
# 555956                       Debt is not mine                          NaN
#
#                                   company_public_response  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
# 6                                                     NaN
# 7                                                     NaN
# 8                                                     NaN
# 9                                                     NaN
# 10                                                    NaN
# 11                                                    NaN
# 12                                                    NaN
# 13                                                    NaN
# 14                                                    NaN
# 15                                                    NaN
# 16                                                    NaN
# 17                                                    NaN
# 18                                                    NaN
# 19                                                    NaN
# 20                                                    NaN
# 21                                                    NaN
# 22                                                    NaN
# 23                                                    NaN
# 24                                                    NaN
# 25                                                    NaN
# 26                                                    NaN
# 27                                                    NaN
# 28                                                    NaN
# 29                                                    NaN
# ...                                                   ...
# 555927                                                NaN
# 555928                                                NaN
# 555929                                                NaN
# 555930                                                NaN
# 555931                                                NaN
# 555932   Company chooses not to provide a public response
# 555933                                                NaN
# 555934  Company believes it acted appropriately as aut...
# 555935                                                NaN
# 555936                                                NaN
# 555937                                                NaN
# 555938                                                NaN
# 555939                                                NaN
# 555940                                                NaN
# 555941   Company chooses not to provide a public response
# 555942                                                NaN
# 555943   Company chooses not to provide a public response
# 555944  Company believes it acted appropriately as aut...
# 555945                                                NaN
# 555946                                                NaN
# 555947                                                NaN
# 555948                                                NaN
# 555949  Company has responded to the consumer and the ...
# 555950                                                NaN
# 555951                                                NaN
# 555952                                                NaN
# 555953                                                NaN
# 555954                                                NaN
# 555955                                                NaN
# 555956                                                NaN
#
#                                        company state zipcode  \
# 0                                 U.S. Bancorp    CA   95993
# 1                        Wells Fargo & Company    CA   91104
# 2                        Wells Fargo & Company    NY   11764
# 3                      Navient Solutions, Inc.    MD   21402
# 4              Resurgent Capital Services L.P.    GA   30106
# 5                                  Capital One    NY   12206
# 6                        Wells Fargo & Company    AZ   85730
# 7                              Bank of America    IL   60660
# 8                              Bank of America    GA   30016
# 9                         SunTrust Banks, Inc.    CA   94551
# 10                  Convergent Resources, Inc.    NC   27545
# 11                                 Capital One    NC   27614
# 12                             Bank of America    TX   75023
# 13                       Wells Fargo & Company    TX   78244
# 14                             Bank of America    GA   30132
# 15                       PayPal Holdings, Inc.    DC   20003
# 16                   Van Ru Credit Corporation    KY   40508
# 17      TransUnion Intermediate Holdings, Inc.    IL   62060
# 18                       Allied Interstate LLC    GA   30039
# 19                                     Equifax    RI   02921
# 20                             Bank of America    TN   37874
# 21                     Navient Solutions, Inc.    GA   30039
# 22          Carrington Mortgage Holdings, LLC.    AR   72113
# 23                       Wells Fargo & Company    GA   30132
# 24            HSBC North America Holdings Inc.    IL   62034
# 25                   Enova International, Inc.    AL   35473
# 26                       Wells Fargo & Company    NC   28753
# 27                             Bank of America    NJ   08512
# 28                        SunTrust Banks, Inc.    VA   22151
# 29                         Nationstar Mortgage    FL   34684
# ...                                        ...   ...     ...
# 555927                                 Equifax   NaN     NaN
# 555928                         FirstMerit Bank   NaN     NaN
# 555929                             Capital One   NaN     NaN
# 555930        HSBC North America Holdings Inc.   NaN     NaN
# 555931                                   Ocwen   NaN     NaN
# 555932                          BB&T Financial   NaN     NaN
# 555933          Citizens Financial Group, Inc.   NaN     NaN
# 555934         Select Portfolio Servicing, Inc   NaN     NaN
# 555935                             Capital One   NaN     NaN
# 555936                       TCF National Bank   NaN     NaN
# 555937                                Experian   NaN     NaN
# 555938                                Citibank   NaN     NaN
# 555939                   Wells Fargo & Company   NaN     NaN
# 555940      Carrington Mortgage Holdings, LLC.   NaN     NaN
# 555941                                Citibank   NaN     NaN
# 555942             Bayview Loan Servicing, LLC   NaN     NaN
# 555943                                Citibank   NaN     NaN
# 555944                Pressler & Pressler, LLP   NaN     NaN
# 555945               Empowerment Ventures, LLC   NaN     NaN
# 555946                                   Ocwen   NaN     NaN
# 555947                                Citibank   NaN     NaN
# 555948                   Wells Fargo & Company   NaN     NaN
# 555949                            U.S. Bancorp   NaN     NaN
# 555950                   Allied Interstate LLC   NaN     NaN
# 555951                             Capital One   NaN     NaN
# 555952                         Bank of America   NaN     NaN
# 555953            Residential Credit Solutions   NaN     NaN
# 555954                          BB&T Financial   NaN     NaN
# 555955                   Global Recovery Group   NaN     NaN
# 555956            CCS Financial Services, Inc.   NaN     NaN
#
#                                  tags consumer_consent_provided submitted_via  \
# 0                                 NaN                       NaN      Referral
# 1                                 NaN                       NaN      Referral
# 2                                 NaN                       NaN   Postal mail
# 3                                 NaN                       NaN         Email
# 4                                 NaN                       NaN           Web
# 5                                 NaN                       NaN         Phone
# 6                                 NaN                       NaN   Postal mail
# 7                                 NaN                       NaN      Referral
# 8                                 NaN                       NaN      Referral
# 9                                 NaN                       NaN           Web
# 10                                NaN                       NaN           Web
# 11                                NaN                       NaN           Fax
# 12                                NaN                       NaN           Web
# 13                                NaN                       NaN           Fax
# 14                                NaN                       NaN           Web
# 15                                NaN                       NaN           Web
# 16                                NaN                       NaN         Phone
# 17                                NaN                       NaN           Web
# 18                                NaN                       NaN         Phone
# 19                                NaN                       NaN   Postal mail
# 20                     Older American                       NaN         Phone
# 21                                NaN                       NaN         Phone
# 22                                NaN                       NaN           Web
# 23                                NaN                       NaN           Web
# 24                                NaN                       NaN           Web
# 25                                NaN                       NaN           Web
# 26                                NaN                       NaN           Web
# 27                                NaN                       NaN           Web
# 28                                NaN                       NaN           Web
# 29                     Older American                       NaN         Phone
# ...                               ...                       ...           ...
# 555927                            NaN                       NaN         Phone
# 555928                            NaN                       NaN      Referral
# 555929                            NaN                       NaN      Referral
# 555930                            NaN                       NaN      Referral
# 555931                            NaN                       NaN      Referral
# 555932                            NaN                       NaN      Referral
# 555933                            NaN                       NaN      Referral
# 555934                            NaN                       NaN      Referral
# 555935                            NaN                       NaN         Phone
# 555936                            NaN                       NaN      Referral
# 555937                            NaN                       NaN   Postal mail
# 555938                 Older American                       NaN         Phone
# 555939                            NaN                       NaN      Referral
# 555940                            NaN                       NaN      Referral
# 555941                            NaN                       NaN      Referral
# 555942                            NaN                       NaN   Postal mail
# 555943                            NaN                       NaN         Phone
# 555944                            NaN                       NaN      Referral
# 555945                            NaN                       NaN         Phone
# 555946                            NaN                       NaN      Referral
# 555947                            NaN                       NaN           Fax
# 555948                            NaN                       NaN         Phone
# 555949                 Older American                       NaN           Fax
# 555950                            NaN                       NaN         Phone
# 555951                            NaN                       NaN         Phone
# 555952                            NaN                       NaN      Referral
# 555953  Older American, Servicemember                       NaN      Referral
# 555954                            NaN                       NaN         Phone
# 555955                            NaN                       NaN         Phone
# 555956                            NaN                       NaN         Phone
#
#        date_sent_to_company     company_response_to_consumer timely_response  \
# 0                09/03/2013          Closed with explanation             Yes
# 1                09/03/2013          Closed with explanation             Yes
# 2                09/18/2013          Closed with explanation             Yes
# 3                08/30/2013          Closed with explanation             Yes
# 4                08/30/2013          Closed with explanation             Yes
# 5                09/03/2013          Closed with explanation             Yes
# 6                09/05/2013          Closed with explanation             Yes
# 7                09/04/2013          Closed with explanation             Yes
# 8                09/04/2013          Closed with explanation             Yes
# 9                09/18/2013          Closed with explanation             Yes
# 10               08/30/2013          Closed with explanation             Yes
# 11               09/03/2013          Closed with explanation             Yes
# 12               09/03/2013          Closed with explanation             Yes
# 13               09/03/2013          Closed with explanation             Yes
# 14               09/14/2013          Closed with explanation             Yes
# 15               09/17/2013      Closed with monetary relief             Yes
# 16               09/18/2013  Closed with non-monetary relief             Yes
# 17               09/24/2013  Closed with non-monetary relief             Yes
# 18               09/25/2013  Closed with non-monetary relief             Yes
# 19               10/10/2013          Closed with explanation             Yes
# 20               11/04/2013          Closed with explanation             Yes
# 21               09/25/2013      Closed with monetary relief             Yes
# 22               09/25/2013          Closed with explanation             Yes
# 23               09/14/2013          Closed with explanation             Yes
# 24               09/11/2013          Closed with explanation             Yes
# 25               09/26/2013          Closed with explanation             Yes
# 26               09/25/2013      Closed with monetary relief             Yes
# 27               09/19/2013          Closed with explanation             Yes
# 28               09/17/2013          Closed with explanation             Yes
# 29               09/04/2013          Closed with explanation             Yes
# ...                     ...                              ...             ...
# 555927           12/11/2015          Closed with explanation             Yes
# 555928           10/19/2015          Closed with explanation             Yes
# 555929           08/10/2015          Closed with explanation             Yes
# 555930           07/16/2013          Closed with explanation             Yes
# 555931           12/09/2013          Closed with explanation             Yes
# 555932           11/25/2015          Closed with explanation             Yes
# 555933           09/11/2012          Closed with explanation             Yes
# 555934           01/21/2016          Closed with explanation             Yes
# 555935           03/23/2015          Closed with explanation             Yes
# 555936           09/20/2012          Closed with explanation             Yes
# 555937           08/04/2014          Closed with explanation             Yes
# 555938           09/10/2012          Closed with explanation             Yes
# 555939           04/15/2013                           Closed             Yes
# 555940           11/10/2014          Closed with explanation             Yes
# 555941           01/12/2016          Closed with explanation             Yes
# 555942           09/05/2015          Closed with explanation             Yes
# 555943           04/14/2015  Closed with non-monetary relief             Yes
# 555944           12/28/2015          Closed with explanation             Yes
# 555945           11/13/2015  Closed with non-monetary relief             Yes
# 555946           06/04/2014          Closed with explanation             Yes
# 555947           10/09/2012          Closed with explanation             Yes
# 555948           05/14/2014          Closed with explanation             Yes
# 555949           03/16/2016      Closed with monetary relief             Yes
# 555950           01/29/2014  Closed with non-monetary relief             Yes
# 555951           05/18/2012          Closed with explanation             Yes
# 555952           07/07/2014          Closed with explanation             Yes
# 555953           07/23/2014          Closed with explanation              No
# 555954           11/18/2013          Closed with explanation             Yes
# 555955           04/14/2015                Untimely response              No
# 555956           08/18/2014          Closed with explanation             Yes
#
#        consumer_disputed?  complaint_id
# 0                     Yes        511074
# 1                     Yes        511080
# 2                      No        510473
# 3                     Yes        510326
# 4                     Yes        511067
# 5                     Yes        510098
# 6                      No        511062
# 7                      No        511116
# 8                      No        511091
# 9                     Yes        530602
# 10                     No        509988
# 11                    Yes        511084
# 12                     No        511090
# 13                    Yes        510129
# 14                     No        521353
# 15                     No        531853
# 16                     No        530622
# 17                     No        540835
# 18                     No        540355
# 19                     No        531346
# 20                    Yes        530624
# 21                     No        540356
# 22                     No        540357
# 23                     No        521354
# 24                     No        521356
# 25                     No        540359
# 26                     No        540360
# 27                     No        521360
# 28                     No        531855
# 29                    Yes        510410
# ...                   ...           ...
# 555927                 No       1686083
# 555928                 No       1606184
# 555929                 No       1504319
# 555930                 No        456162
# 555931                 No        622278
# 555932                 No       1663619
# 555933                 No        149982
# 555934                 No       1746686
# 555935                 No       1294117
# 555936                 No        153212
# 555937                 No        917675
# 555938                 No        149596
# 555939                 No        381723
# 555940                 No       1102261
# 555941                Yes       1728675
# 555942                 No       1543249
# 555943                 No       1327864
# 555944                 No       1714883
# 555945                 No       1627327
# 555946                 No        874777
# 555947                 No        166125
# 555948                Yes        844996
# 555949                 No       1834823
# 555950                 No        678382
# 555951                 No         82674
# 555952                 No        919529
# 555953                 No        918447
# 555954                 No        114550
# 555955                 No       1329963
# 555956                 No        984116
#
# [555957 rows x 18 columns]

# %%
df.shape
# Out:
# (555957, 18)

# %%
df.columns
# Out:
# Index(['date_received', 'product', 'sub_product', 'issue', 'sub_issue',
#        'consumer_complaint_narrative', 'company_public_response', 'company',
#        'state', 'zipcode', 'tags', 'consumer_consent_provided',
#        'submitted_via', 'date_sent_to_company', 'company_response_to_consumer',
#        'timely_response', 'consumer_disputed?', 'complaint_id'],
#       dtype='object')

# %%
df["product"].value_counts()
# Out:
# Mortgage                   186475
# Debt collection            101052
# Credit reporting            91854
# Credit card                 66468
# Bank account or service     62563
# Consumer Loan               20990
# Student loan                15839
# Payday loan                  3877
# Money transfers              3812
# Prepaid card                 2470
# Other financial service       557
# Name: product, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555957 entries, 0 to 555956
# Data columns (total 18 columns):
# date_received                   555957 non-null object
# product                         555957 non-null object
# sub_product                     397635 non-null object
# issue                           555957 non-null object
# sub_issue                       212622 non-null object
# consumer_complaint_narrative    66806 non-null object
# company_public_response         85124 non-null object
# company                         555957 non-null object
# state                           551070 non-null object
# zipcode                         551452 non-null object
# tags                            77959 non-null object
# consumer_consent_provided       123458 non-null object
# submitted_via                   555957 non-null object
# date_sent_to_company            555957 non-null object
# company_response_to_consumer    555957 non-null object
# timely_response                 555957 non-null object
# consumer_disputed?              555957 non-null object
# complaint_id                    555957 non-null int64
# dtypes: int64(1), object(17)
# memory usage: 76.3+ MB

# %%
col = df[["product","consumer_complaint_narrative"]]
type(col)
# Out:
# pandas.core.frame.DataFrame

# %%
df = df[pd.notnull(df['consumer_complaint_narrative'])]

# %%
df.columns
# Out:
# Index(['date_received', 'product', 'sub_product', 'issue', 'sub_issue',
#        'consumer_complaint_narrative', 'company_public_response', 'company',
#        'state', 'zipcode', 'tags', 'consumer_consent_provided',
#        'submitted_via', 'date_sent_to_company', 'company_response_to_consumer',
#        'timely_response', 'consumer_disputed?', 'complaint_id'],
#       dtype='object')

# %%
category_id_df = df[['product', 'category_id']].drop_duplicates().sort_values('category_id')
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['category_id', 'product']].values)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-b0c18b48ac4c> in <module>()
# ----> 1 category_id_df = df[['product', 'category_id']].drop_duplicates().sort_values('category_id')
#       2 category_to_id = dict(category_id_df.values)
#       3 id_to_category = dict(category_id_df[['category_id', 'product']].values)
#       4 df.head()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1250             if not(self.name == 'loc' and not raise_missing):
#    1251                 not_found = list(set(key) - set(ax))
# -> 1252                 raise KeyError("{} not in index".format(not_found))
#    1253
#    1254             # we skip the warning on Categorical/Interval
#
# KeyError: "['category_id'] not in index"

# %%
df = pd.DataFrame(columns=["A","B"])
df["A"]="aa","bb"
df["B"]= 12,45
df
# Out:
#     A    B
# 0  aa  NaN
# 1  bb  NaN
